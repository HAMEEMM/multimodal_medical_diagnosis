# %% [markdown]
# # Audio and Text Classification Environment Setup
#
# This notebook establishes a comprehensive environment for medical audio and text classification by importing essential libraries:
#
# - **Core Libraries:** pandas for data manipulation, numpy for numerical operations, matplotlib/seaborn for visualization
# - **Audio Processing Tools:** librosa for audio analysis, soundfile for audio I/O, and scipy for signal processing
# - **NLP Tools:** NLTK, TextBlob, and wordcloud for natural language processing tasks
# - **Machine Learning:** scikit-learn for traditional ML algorithms and evaluation metrics
# - **Deep Learning:** TensorFlow/Keras for neural network implementations
#
# The setup includes error handling, warning suppression, and automatic resource downloads to ensure a seamless workflow. Random seeds are set for reproducibility, and visualization settings are configured for consistent, high-quality charts and graphs.

# %%
# Audio and Text Classification Environment Setup

# Suppress specific warnings
import warnings

# Filter out pkg_resources deprecation warning from textstat
warnings.filterwarnings("ignore", 
                       message="pkg_resources is deprecated as an API", 
                       category=UserWarning)

# Filter out all Google Protobuf version warnings
warnings.filterwarnings("ignore", 
                       message="Protobuf gencode version", 
                       category=UserWarning)

# Filter any other warnings you want to suppress
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Core imports with error handling
try:
    import logging
except ImportError as e:
    print("Please install the required package name logging so the environment is ready for audio and text classification development")
    raise

try:
    import tensorflow as tf  # Google's deep learning framework
    # Option 1: Set TensorFlow logging level to ERROR (suppresses warnings)
    tf.get_logger().setLevel('ERROR')
    # Option 2: Or use Python's logging module to filter TensorFlow warnings
    logging.getLogger('tensorflow').setLevel(logging.ERROR)
except ImportError as e:
    print("Please install the required package name tensorflow so the environment is ready for audio and text classification development")
    raise

# Core data manipulation and visualization libraries
try:
    import pandas as pd  # For data manipulation and analysis with DataFrames
except ImportError as e:
    print("Please install the required package name pandas so the environment is ready for audio and text classification development")
    raise

try:
    import numpy as np  # For numerical operations and array handling
except ImportError as e:
    print("Please install the required package name numpy so the environment is ready for audio and text classification development")
    raise

try:
    import matplotlib.pyplot as plt  # For creating static plots and visualizations
    from mpl_toolkits.mplot3d import Axes3D  # For 3D plotting capabilities
except ImportError as e:
    print("Please install the required package name matplotlib so the environment is ready for audio and text classification development")
    raise

try:
    import seaborn as sns  # For statistical data visualization with attractive styling
except ImportError as e:
    print("Please install the required package name seaborn so the environment is ready for audio and text classification development")
    raise

try:
    import plotly.express as px  # For interactive plotting with simple syntax
    import plotly.graph_objects as go  # For advanced interactive plotting with detailed control
    from plotly.subplots import make_subplots  # For creating subplot layouts in plotly
except ImportError as e:
    print("Please install the required package name plotly so the environment is ready for audio and text classification development")
    raise

try:
    import re  # For regular expression operations (text pattern matching)
except ImportError as e:
    print("Please install the required package name re so the environment is ready for audio and text classification development")
    raise

try:
    import string  # For string constants and operations
except ImportError as e:
    print("Please install the required package name string so the environment is ready for audio and text classification development")
    raise

try:
    import os  # For operating system interface (file/directory operations)
except ImportError as e:
    print("Please install the required package name os so the environment is ready for audio and text classification development")
    raise

# Audio processing libraries with error handling
try:
    import librosa  # For audio and music analysis
    import librosa.display  # For audio visualization
except ImportError as e:
    print("Please install the required package name librosa so the environment is ready for audio and text classification development")
    raise

try:
    import soundfile as sf  # For reading and writing sound files
except ImportError as e:
    print("Please install the required package name soundfile so the environment is ready for audio and text classification development")
    raise

try:
    from scipy import signal  # For signal processing
    import scipy.stats  # For statistical functions
except ImportError as e:
    print("Please install the required package name scipy so the environment is ready for audio and text classification development")
    raise

try:
    from wordcloud import WordCloud  # For generating word cloud visualizations
except ImportError as e:
    print("Please install the required package name wordcloud so the environment is ready for audio and text classification development")
    raise

try:
    from collections import Counter  # Import Counter for counting frequencies in processed data
except ImportError as e:
    print("Please install the required package name collections so the environment is ready for audio and text classification development")
    raise

try:
    from PIL import Image  # For image processing and manipulation
except ImportError as e:
    print("Please install the required package name Pillow so the environment is ready for audio and text classification development")
    raise

try:
    from tabulate import tabulate  # Display results in a table format
except ImportError as e:
    print("Please install the required package name tabulate so the environment is ready for audio and text classification development")
    raise

try:
    import joblib  # For saving and loading Python objects (like trained models) to/from disk
except ImportError as e:
    print("Please install the required package name joblib so the environment is ready for audio and text classification development")
    raise

try:
    import time  # For time-related functions (e.g., measuring execution time)
except ImportError as e:
    print("Please install the required package name time so the environment is ready for audio and text classification development")
    raise

try:
    import math  # For mathematical operations (e.g., square root, logarithm)
except ImportError as e:
    print("Please install the required package name math so the environment is ready for audio and text classification development")
    raise

try:
    import h5py  # For reading and writing HDF5 files (hierarchical data format)
    from h5py import File  # For reading and writing HDF5 files (hierarchical data format)
except ImportError as e:
    print("Please install the required package name h5py so the environment is ready for audio and text classification development")
    raise

try:
    import random  # For generating random numbers and making random choices
except ImportError as e:
    print("Please install the required package name random so the environment is ready for audio and text classification development")
    raise

try:
    from tqdm import tqdm  # For displaying progress bars in loops
except ImportError as e:
    print("Please install the required package name tqdm so the environment is ready for audio and text classification development")
    raise

try:
    from gensim.models import Word2Vec, FastText  # For word embeddings and vector representations of words
except ImportError as e:
    print("Please install the required package name gensim so the environment is ready for audio and text classification development")
    raise

# NLP libraries with error handling
try:
    import nltk  # Natural Language Toolkit for text processing
    from nltk.corpus import stopwords  # Pre-defined list of common words to filter out
    from nltk.tokenize import word_tokenize  # For splitting text into individual words/tokens
    from nltk.stem import WordNetLemmatizer, PorterStemmer  # For reducing words to root forms
except ImportError as e:
    print("Please install the required package name nltk so the environment is ready for audio and text classification development")
    raise

try:
    from textblob import TextBlob  # For sentiment analysis and text processing
except ImportError as e:
    print("Please install the required package name textblob so the environment is ready for audio and text classification development")
    raise

try:
    import textstat  # For calculating text readability and complexity metrics
except ImportError as e:
    print("Please install the required package name textstat so the environment is ready for audio and text classification development")
    raise

try:
    import scipy.sparse  # For working with sparse matrices (memory-efficient storage of large matrices)
except ImportError as e:
    print("Please install the required package name scipy so the environment is ready for audio and text classification development")
    raise

# Machine learning libraries with error handling
try:
    import sklearn  # Comprehensive machine learning library
    from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score, RandomizedSearchCV  # For data splitting and model evaluation
    from sklearn.preprocessing import LabelEncoder, label_binarize, StandardScaler, RobustScaler  # For converting categorical labels to numerical format and scaling
    from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer  # For converting text to numerical features
    from sklearn.naive_bayes import MultinomialNB, GaussianNB  # Naive Bayes classifiers
    from sklearn.linear_model import LogisticRegression, RidgeClassifier  # Linear models for classification tasks
    from sklearn.svm import LinearSVC, SVC  # Support Vector Machine for classification
    from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier, VotingClassifier  # Ensemble methods using multiple decision trees
    from sklearn.neighbors import KNeighborsClassifier  # K-Nearest Neighbors classifier
    from sklearn.tree import DecisionTreeClassifier  # Decision tree classifier
    from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support  # For model performance evaluation
    from sklearn.metrics import roc_curve, auc, precision_score, recall_score, f1_score  # For ROC curve analysis and AUC calculation
    from sklearn.pipeline import Pipeline  # For chaining preprocessing and model steps
    from sklearn.metrics import cohen_kappa_score, matthews_corrcoef, roc_auc_score  # For various evaluation metrics
    from sklearn.utils.class_weight import compute_class_weight  # For computing class weights to handle imbalanced datasets
    from sklearn.metrics.pairwise import cosine_similarity  # For calculating similarity between vectors
    from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, RFE, VarianceThreshold  # For feature selection methods
    from sklearn.decomposition import PCA, TruncatedSVD, LatentDirichletAllocation  # For dimensionality reduction
    from sklearn.discriminant_analysis import LinearDiscriminantAnalysis  # For linear discriminant analysis
except ImportError as e:
    print("Please install the required package name scikit-learn so the environment is ready for audio and text classification development")
    raise

try:
    from imblearn.over_sampling import SMOTE, BorderlineSMOTE  # For handling imbalanced datasets by generating synthetic samples
    from imblearn.combine import SMOTETomek  # For combined over/under-sampling
    from imblearn.under_sampling import RandomUnderSampler  # For undersampling techniques
except ImportError as e:
    print("Please install the required package name imbalanced-learn so the environment is ready for audio and text classification development")
    raise

# Deep learning libraries with error handling
try:
    from tensorflow.keras.models import Sequential  # For building neural networks layer by layer
    from tensorflow.keras.layers import Dense, Dropout, Embedding, GlobalMaxPooling1D, Conv1D, MaxPooling1D, GlobalMaxPooling1D  # Various neural network layer types
    from tensorflow.keras.preprocessing.text import Tokenizer  # For converting text to sequences of numbers
    from tensorflow.keras.preprocessing.sequence import pad_sequences  # For making all text sequences the same length
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint  # For controlling training process and saving best models
    from tensorflow.keras.utils import to_categorical  # For one-hot encoding categorical variables
except ImportError as e:
    print("Please install the required package name tensorflow so the environment is ready for audio and text classification development")
    raise

# Additional imports for Phase 6 compatibility
try:
    import json  # For JSON file handling
except ImportError as e:
    print("Please install the required package name json so the environment is ready for audio and text classification development")
    raise

# Suppress warnings after successful imports
warnings.filterwarnings('ignore')  # Hide warning messages to keep output clean

# Download NLTK resources with error handling
try:
    try:
        nltk.data.find('tokenizers/punkt')  # Check if punkt tokenizer is already downloaded
        nltk.data.find('corpora/stopwords')  # Check if stopwords corpus is already downloaded
        nltk.data.find('corpora/wordnet')  # Check if wordnet corpus is already downloaded
    except LookupError:
        print("Downloading required NLTK data...")
        nltk.download('punkt', quiet=True)  # Download sentence tokenizer if not found
        nltk.download('stopwords', quiet=True)  # Download list of common words if not found
        nltk.download('wordnet', quiet=True)  # Download word database for lemmatization if not found
        print("✓ NLTK data downloaded successfully")
except Exception as e:
    print(f"Warning: Could not download NLTK data: {str(e)}")
    print("Please ensure you have internet connectivity and try again")

# Set random seeds for reproducibility
try:
    np.random.seed(42)  # Ensure numpy random operations produce consistent results
    tf.random.set_seed(42)  # Ensure tensorflow random operations produce consistent results
    random.seed(42)  # Ensure Python random operations produce consistent results
except Exception as e:
    print(f"Warning: Could not set random seeds: {str(e)}")

# Configure visualization settings
try:
    plt.style.use('fivethirtyeight')  # Apply FiveThirtyEight website's plotting style
    sns.set(style='whitegrid')  # Set seaborn to use white background with grid lines
except Exception as e:
    print(f"Warning: Could not configure visualization settings: {str(e)}")

# Display versions of key libraries for compatibility verification
try:
    print(f"Pandas version: {pd.__version__}")  # Show pandas version for compatibility checking
    print(f"NumPy version: {np.__version__}")  # Show numpy version for compatibility checking
    print(f"TensorFlow version: {tf.__version__}")  # Show tensorflow version for compatibility checking
    print(f"Scikit-learn version: {sklearn.__version__}")  # Show scikit-learn version for compatibility checking
    print(f"Librosa version: {librosa.__version__}")  # Show librosa version for compatibility checking
    print("All importation is completed from the packages and libraries that have been installed.")  # Confirmation message
    print("The environment is now ready for audio and text classification development!")  # Final confirmation message
except Exception as e:
    print(f"Warning: Could not display all version information: {str(e)}") # This is not critical but useful for debugging
    print("However, the environment setup appears to be successful.") # Final confirmation message
    print("The environment is now ready for audio and text classification development!") # Final confirmation message
    # END OF THE AUDIO AND TEXT CLASSIFICATION ENVIRONMENT SETUP SCRIPT
    # ============================================================================================
# Out:
# ...
# ✓ NLTK data downloaded successfully
# Pandas version: 2.3.1
# NumPy version: 1.26.4
# TensorFlow version: 2.19.0
# Scikit-learn version: 1.6.1
# Librosa version: 0.11.0
# All importation is completed from the packages and libraries that have been installed.
# The environment is now ready for audio and text classification development!
# ✓ NLTK data downloaded successfully
# Pandas version: 2.3.1
# NumPy version: 1.26.4
# TensorFlow version: 2.19.0
# Scikit-learn version: 1.6.1
# Librosa version: 0.11.0
# All importation is completed from the packages and libraries that have been installed.
# The environment is now ready for audio and text classification development!

# %% [markdown]
# ## Audio and Text Classification Development Life Cycle Overview

# %% [markdown]
# ### Phase1: NLP and Deep Learning for Audio and Text Classification in Medical Diagnosis
#
# Audio and Text Classification Research Question
#
# RQ3: How effective is NLP in classifying patient symptoms from audio and text data on the population level?
# - **H30**: Audio and text analysis of patient symptoms yields both precision and recall metrics that are insufficient for effective provider decision support.
# - **H3a**: Audio and text analysis of patient symptoms results in precision and recall sufficient for provider decision support.

# %%
# Print the Audio and Text Classification Research Question and Hypotheses
print("=" * 80)
print("AUDIO AND TEXT CLASSIFICATION RESEARCH QUESTIONS AND HYPOTHESES")
print("=" * 80)
print("\nRQ3: What is the effectiveness of the audio processing algorithm in classifying patient symptoms from audio data on the population level?\n")
print("- H30: Audio and text analysis of patient symptoms yields both precision and recall metrics that are insufficient for effective provider decision support.")
print("- H3a: Audio and text analysis of patient symptoms results in precision and recall sufficient for provider decision support.")
print("=" * 80)
print("PHASE 1 COMPLETED: PROBLEM DEFINITION")
print("=" * 80)
# END OF PHASE 1: AUDIO PROBLEM DEFINITION SCRIPT
# =============================================================================

# %% [markdown]
# ### Phase 2: Audio and Text Data Foundation and Exploration (Data Collection)
#
# This section implements the **data foundation** phase of our audio classification pipeline, analyzing a medical audio dataset with patient recordings across 25 diagnostic categories.
#
# **Key Elements:**
# - **Audio Files (`file_name`)**: Audio file paths that will serve as input features for processing
# - **Diagnostic Categories (`prompt`)**: Classification targets, including conditions like "Heart hurts", "Joint pain", and "Skin issue"
# - **Patient Descriptions (`phrase`)**: Raw symptom reports that will serve as input features
# - **Distribution Analysis**: Visualizes class imbalance across diagnostic categories
# - **Data Quality Assessment**: Identifies missing files, invalid audio data, and other quality concerns before preprocessing

# %% [markdown]
# ### Phase 3: Audio and Text Data Cleaning and Preprocessing (Data Preparation)

# %% [markdown]
# ### Phase 4: Audio and Text  Feature Engineering and Selection

# %% [markdown]
# ### Phase 5: Audio and Text Model Selection

# %% [markdown]
# ### Phase 6: Audio and Text Model Training

# %% [markdown]
# ### Phase 7: Audio and Text Model Evaluation

# %% [markdown]
# #### 7.1: Audio and Text Classification Research Hypothesis Evaluation
