# %% [markdown]
# # Audio and Text Classification Environment Setup
#
# This notebook establishes a comprehensive environment for medical audio and text classification by importing essential libraries:
#
# - **Core Libraries:** pandas for data manipulation, numpy for numerical operations, matplotlib/seaborn for visualization
# - **Audio Processing Tools:** librosa for audio analysis, soundfile for audio I/O, and scipy for signal processing
# - **NLP Tools:** NLTK, TextBlob, and wordcloud for natural language processing tasks
# - **Machine Learning:** scikit-learn for traditional ML algorithms and evaluation metrics
# - **Deep Learning:** TensorFlow/Keras for neural network implementations
#
# The setup includes error handling, warning suppression, and automatic resource downloads to ensure a seamless workflow. Random seeds are set for reproducibility, and visualization settings are configured for consistent, high-quality charts and graphs.

# %%
# Audio and Text Classification Environment Setup

# Suppress specific warnings
import warnings

# Filter out pkg_resources deprecation warning from textstat
warnings.filterwarnings("ignore", 
                       message="pkg_resources is deprecated as an API", 
                       category=UserWarning)

# Filter out all Google Protobuf version warnings
warnings.filterwarnings("ignore", 
                       message="Protobuf gencode version", 
                       category=UserWarning)

# Filter any other warnings you want to suppress
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Core imports with error handling
try:
    import logging
except ImportError as e:
    print("Please install the required package name logging so the environment is ready for audio and text classification development")
    raise

try:
    import tensorflow as tf  # Google's deep learning framework
    # Option 1: Set TensorFlow logging level to ERROR (suppresses warnings)
    tf.get_logger().setLevel('ERROR')
    # Option 2: Or use Python's logging module to filter TensorFlow warnings
    logging.getLogger('tensorflow').setLevel(logging.ERROR)
except ImportError as e:
    print("Please install the required package name tensorflow so the environment is ready for audio and text classification development")
    raise

# Core data manipulation and visualization libraries
try:
    import pandas as pd  # For data manipulation and analysis with DataFrames
except ImportError as e:
    print("Please install the required package name pandas so the environment is ready for audio and text classification development")
    raise

try:
    import numpy as np  # For numerical operations and array handling
except ImportError as e:
    print("Please install the required package name numpy so the environment is ready for audio and text classification development")
    raise

try:
    import matplotlib.pyplot as plt  # For creating static plots and visualizations
    from mpl_toolkits.mplot3d import Axes3D  # For 3D plotting capabilities
except ImportError as e:
    print("Please install the required package name matplotlib so the environment is ready for audio and text classification development")
    raise

try:
    import seaborn as sns  # For statistical data visualization with attractive styling
except ImportError as e:
    print("Please install the required package name seaborn so the environment is ready for audio and text classification development")
    raise

try:
    import plotly.express as px  # For interactive plotting with simple syntax
    import plotly.graph_objects as go  # For advanced interactive plotting with detailed control
    from plotly.subplots import make_subplots  # For creating subplot layouts in plotly
except ImportError as e:
    print("Please install the required package name plotly so the environment is ready for audio and text classification development")
    raise

try:
    import re  # For regular expression operations (text pattern matching)
except ImportError as e:
    print("Please install the required package name re so the environment is ready for audio and text classification development")
    raise

try:
    import string  # For string constants and operations
except ImportError as e:
    print("Please install the required package name string so the environment is ready for audio and text classification development")
    raise

try:
    import os  # For operating system interface (file/directory operations)
except ImportError as e:
    print("Please install the required package name os so the environment is ready for audio and text classification development")
    raise

# Audio processing libraries with error handling
try:
    import librosa  # For audio and music analysis
    import librosa.display  # For audio visualization
except ImportError as e:
    print("Please install the required package name librosa so the environment is ready for audio and text classification development")
    raise

try:
    import soundfile as sf  # For reading and writing sound files
except ImportError as e:
    print("Please install the required package name soundfile so the environment is ready for audio and text classification development")
    raise

try:
    from scipy import signal  # For signal processing
    import scipy.stats  # For statistical functions
except ImportError as e:
    print("Please install the required package name scipy so the environment is ready for audio and text classification development")
    raise

try:
    from wordcloud import WordCloud  # For generating word cloud visualizations
except ImportError as e:
    print("Please install the required package name wordcloud so the environment is ready for audio and text classification development")
    raise

try:
    from collections import Counter  # Import Counter for counting frequencies in processed data
except ImportError as e:
    print("Please install the required package name collections so the environment is ready for audio and text classification development")
    raise

try:
    from PIL import Image  # For image processing and manipulation
except ImportError as e:
    print("Please install the required package name Pillow so the environment is ready for audio and text classification development")
    raise

try:
    from tabulate import tabulate  # Display results in a table format
except ImportError as e:
    print("Please install the required package name tabulate so the environment is ready for audio and text classification development")
    raise

try:
    import joblib  # For saving and loading Python objects (like trained models) to/from disk
except ImportError as e:
    print("Please install the required package name joblib so the environment is ready for audio and text classification development")
    raise

try:
    import time  # For time-related functions (e.g., measuring execution time)
except ImportError as e:
    print("Please install the required package name time so the environment is ready for audio and text classification development")
    raise

try:
    import math  # For mathematical operations (e.g., square root, logarithm)
except ImportError as e:
    print("Please install the required package name math so the environment is ready for audio and text classification development")
    raise

try:
    import h5py  # For reading and writing HDF5 files (hierarchical data format)
    from h5py import File  # For reading and writing HDF5 files (hierarchical data format)
except ImportError as e:
    print("Please install the required package name h5py so the environment is ready for audio and text classification development")
    raise

try:
    import random  # For generating random numbers and making random choices
except ImportError as e:
    print("Please install the required package name random so the environment is ready for audio and text classification development")
    raise

try:
    from tqdm import tqdm  # For displaying progress bars in loops
except ImportError as e:
    print("Please install the required package name tqdm so the environment is ready for audio and text classification development")
    raise

try:
    from gensim.models import Word2Vec, FastText  # For word embeddings and vector representations of words
except ImportError as e:
    print("Please install the required package name gensim so the environment is ready for audio and text classification development")
    raise

# NLP libraries with error handling
try:
    import nltk  # Natural Language Toolkit for text processing
    from nltk.corpus import stopwords  # Pre-defined list of common words to filter out
    from nltk.tokenize import word_tokenize  # For splitting text into individual words/tokens
    from nltk.stem import WordNetLemmatizer, PorterStemmer  # For reducing words to root forms
except ImportError as e:
    print("Please install the required package name nltk so the environment is ready for audio and text classification development")
    raise

try:
    from textblob import TextBlob  # For sentiment analysis and text processing
except ImportError as e:
    print("Please install the required package name textblob so the environment is ready for audio and text classification development")
    raise

try:
    import textstat  # For calculating text readability and complexity metrics
except ImportError as e:
    print("Please install the required package name textstat so the environment is ready for audio and text classification development")
    raise

try:
    import scipy.sparse  # For working with sparse matrices (memory-efficient storage of large matrices)
except ImportError as e:
    print("Please install the required package name scipy so the environment is ready for audio and text classification development")
    raise

# Machine learning libraries with error handling
try:
    import sklearn  # Comprehensive machine learning library
    from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score, RandomizedSearchCV  # For data splitting and model evaluation
    from sklearn.preprocessing import LabelEncoder, label_binarize, StandardScaler, RobustScaler  # For converting categorical labels to numerical format and scaling
    from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer  # For converting text to numerical features
    from sklearn.naive_bayes import MultinomialNB, GaussianNB  # Naive Bayes classifiers
    from sklearn.linear_model import LogisticRegression, RidgeClassifier  # Linear models for classification tasks
    from sklearn.svm import LinearSVC, SVC  # Support Vector Machine for classification
    from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, BaggingClassifier, VotingClassifier  # Ensemble methods using multiple decision trees
    from sklearn.neighbors import KNeighborsClassifier  # K-Nearest Neighbors classifier
    from sklearn.tree import DecisionTreeClassifier  # Decision tree classifier
    from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support  # For model performance evaluation
    from sklearn.metrics import roc_curve, auc, precision_score, recall_score, f1_score  # For ROC curve analysis and AUC calculation
    from sklearn.pipeline import Pipeline  # For chaining preprocessing and model steps
    from sklearn.metrics import cohen_kappa_score, matthews_corrcoef, roc_auc_score  # For various evaluation metrics
    from sklearn.utils.class_weight import compute_class_weight  # For computing class weights to handle imbalanced datasets
    from sklearn.metrics.pairwise import cosine_similarity  # For calculating similarity between vectors
    from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif, RFE, VarianceThreshold  # For feature selection methods
    from sklearn.decomposition import PCA, TruncatedSVD, LatentDirichletAllocation  # For dimensionality reduction
    from sklearn.discriminant_analysis import LinearDiscriminantAnalysis  # For linear discriminant analysis
except ImportError as e:
    print("Please install the required package name scikit-learn so the environment is ready for audio and text classification development")
    raise

try:
    from imblearn.over_sampling import SMOTE, BorderlineSMOTE  # For handling imbalanced datasets by generating synthetic samples
    from imblearn.combine import SMOTETomek  # For combined over/under-sampling
    from imblearn.under_sampling import RandomUnderSampler  # For undersampling techniques
except ImportError as e:
    print("Please install the required package name imbalanced-learn so the environment is ready for audio and text classification development")
    raise

# Deep learning libraries with error handling
try:
    from tensorflow.keras.models import Sequential  # For building neural networks layer by layer
    from tensorflow.keras.layers import Dense, Dropout, Embedding, GlobalMaxPooling1D, Conv1D, MaxPooling1D, GlobalMaxPooling1D  # Various neural network layer types
    from tensorflow.keras.preprocessing.text import Tokenizer  # For converting text to sequences of numbers
    from tensorflow.keras.preprocessing.sequence import pad_sequences  # For making all text sequences the same length
    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint  # For controlling training process and saving best models
    from tensorflow.keras.utils import to_categorical  # For one-hot encoding categorical variables
except ImportError as e:
    print("Please install the required package name tensorflow so the environment is ready for audio and text classification development")
    raise

# Additional imports for Phase 6 compatibility
try:
    import json  # For JSON file handling
except ImportError as e:
    print("Please install the required package name json so the environment is ready for audio and text classification development")
    raise

# Suppress warnings after successful imports
warnings.filterwarnings('ignore')  # Hide warning messages to keep output clean

# Download NLTK resources with error handling
try:
    try:
        nltk.data.find('tokenizers/punkt')  # Check if punkt tokenizer is already downloaded
        nltk.data.find('corpora/stopwords')  # Check if stopwords corpus is already downloaded
        nltk.data.find('corpora/wordnet')  # Check if wordnet corpus is already downloaded
    except LookupError:
        print("Downloading required NLTK data...")
        nltk.download('punkt', quiet=True)  # Download sentence tokenizer if not found
        nltk.download('stopwords', quiet=True)  # Download list of common words if not found
        nltk.download('wordnet', quiet=True)  # Download word database for lemmatization if not found
        print("✓ NLTK data downloaded successfully")
except Exception as e:
    print(f"Warning: Could not download NLTK data: {str(e)}")
    print("Please ensure you have internet connectivity and try again")

# Set random seeds for reproducibility
try:
    np.random.seed(42)  # Ensure numpy random operations produce consistent results
    tf.random.set_seed(42)  # Ensure tensorflow random operations produce consistent results
    random.seed(42)  # Ensure Python random operations produce consistent results
except Exception as e:
    print(f"Warning: Could not set random seeds: {str(e)}")

# Configure visualization settings
try:
    plt.style.use('fivethirtyeight')  # Apply FiveThirtyEight website's plotting style
    sns.set(style='whitegrid')  # Set seaborn to use white background with grid lines
except Exception as e:
    print(f"Warning: Could not configure visualization settings: {str(e)}")

# Display versions of key libraries for compatibility verification
try:
    print(f"Pandas version: {pd.__version__}")  # Show pandas version for compatibility checking
    print(f"NumPy version: {np.__version__}")  # Show numpy version for compatibility checking
    print(f"TensorFlow version: {tf.__version__}")  # Show tensorflow version for compatibility checking
    print(f"Scikit-learn version: {sklearn.__version__}")  # Show scikit-learn version for compatibility checking
    print(f"Librosa version: {librosa.__version__}")  # Show librosa version for compatibility checking
    print("All importation is completed from the packages and libraries that have been installed.")  # Confirmation message
    print("The environment is now ready for audio and text classification development!")  # Final confirmation message
except Exception as e:
    print(f"Warning: Could not display all version information: {str(e)}") # This is not critical but useful for debugging
    print("However, the environment setup appears to be successful.") # Final confirmation message
    print("The environment is now ready for audio and text classification development!") # Final confirmation message
    # END OF THE AUDIO AND TEXT CLASSIFICATION ENVIRONMENT SETUP SCRIPT
    # ============================================================================================
# Out:
# ...
# ✓ NLTK data downloaded successfully
# Pandas version: 2.3.1
# NumPy version: 1.26.4
# TensorFlow version: 2.19.0
# Scikit-learn version: 1.6.1
# Librosa version: 0.11.0
# All importation is completed from the packages and libraries that have been installed.
# The environment is now ready for audio and text classification development!
# ✓ NLTK data downloaded successfully
# Pandas version: 2.3.1
# NumPy version: 1.26.4
# TensorFlow version: 2.19.0
# Scikit-learn version: 1.6.1
# Librosa version: 0.11.0
# All importation is completed from the packages and libraries that have been installed.
# The environment is now ready for audio and text classification development!

# %% [markdown]
# ## Audio and Text Classification Development Life Cycle Overview
#
# This notebook implements a comprehensive multimodal classification pipeline for medical symptom diagnosis, integrating both audio and text processing capabilities through eight key phases:
#
# 1. **Problem Definition**: Framing the multimodal classification task and research questions
# 2. **Data Foundation**: Loading and exploring medical audio files and text data with diagnostic categories
# 3. **Data Preprocessing**: Audio preprocessing, noise reduction, text cleaning, and standardizing formats
# 4. **Feature Engineering**: Extracting audio features (MFCCs, spectrograms) and text features (TF-IDF, embeddings)
# 5. **Model Selection**: Evaluating algorithms from traditional ML to deep learning for both modalities
# 6. **Model Training**: Optimizing selected models with appropriate parameters for each data type
# 7. **Model Evaluation**: Assessing performance with metrics like precision and recall for both audio and text
# 8. **Deployment**: Preparing the integrated model for clinical decision support
#
# The following cell visualizes this workflow as a comprehensive diagram to provide a clear roadmap of the development process, showing how each phase builds upon the previous one and contributes to the final goal of accurate multimodal medical classification combining both audio and text analysis.

# %%
# Audio and Text Classification Development Life Cycle Workflow Diagram
def create_audio_text_classification_workflow():
    """
    Create a comprehensive 2D workflow diagram for audio and text classification development life cycle
    """
    
    # Error handling for missing packages
    try:
        import matplotlib.pyplot as plt
        import matplotlib.patches as patches
        from matplotlib.patches import FancyBboxPatch
        import numpy as np
        print("All required packages imported successfully")
    except ImportError as e:
        print(f"Error importing required packages: {e}")
        print("Please install the missing packages:")
        print("pip install matplotlib numpy")
        return
    
    # Create the figure with larger size for better readability
    fig, ax = plt.subplots(figsize=(28, 20))  # Increased size
    
    # Define the workflow phases and their positions with more spacing
    phases = {
        'Phase 1: Problem Definition': {
            'position': (1, 18),
            'steps': [
                '• Audio and Text Processing for Multimodal Classification',
                '• Audio and Text Classification Environment Setup',
                '• Define research questions and hypotheses',
                '• Establish evaluation criteria for both modalities'
            ],
            'color': '#FF6B6B'
        },
        'Phase 2: Data Foundation and Exploration': {
            'position': (1, 16),
            'steps': [
                '• Load raw medical audio and text dataset',
                '• Identify key variables (file_name, phrase, prompt)',
                '• Print sample data for inspection',
                '• Initial data quality assessment for both modalities',
                '• Create EDA visualizations for audio and text',
                '• Save dataset with key variables'
            ],
            'color': '#4ECDC4'
        },
        'Phase 3: Data Cleaning and Preprocessing': {
            'position': (1, 14),
            'steps': [
                'A. Audio Preprocessing:',
                '  • Audio normalization and noise reduction',
                '  • Sample rate standardization',
                '  • Audio file validation and cleaning',
                'B. Text Preprocessing:',
                '  • Text cleaning and normalization',
                '  • Remove special characters and stopwords',
                '  • Tokenization and lemmatization',
                'C. Data Representation:',
                '  • Label encoding and data splitting',
                '  • Handle class imbalance with SMOTE'
            ],
            'color': '#45B7D1'
        },
        'Phase 4: Feature Engineering': {
            'position': (1, 12),
            'steps': [
                'A. Audio Feature Extraction:',
                '  • MFCCs (Mel-frequency cepstral coefficients)',
                '  • Spectrograms and Mel-spectrograms',
                '  • Chroma features and spectral features',
                'B. Text Feature Extraction:',
                '  • TF-IDF vectorization',
                '  • Word embeddings (Word2Vec, FastText)',
                '  • N-gram features and sentiment analysis',
                'C. Feature Selection:',
                '  • Statistical feature selection',
                '  • Dimensionality reduction (PCA, LDA)'
            ],
            'color': '#96CEB4'
        },
        'Phase 5: Model Selection': {
            'position': (1, 10),
            'steps': [
                'A. Candidate Models:',
                '  • Traditional ML: SVM, Random Forest, KNN',
                '  • Deep Learning: CNN, RNN, FNN',
                '  • Multimodal fusion strategies',
                'B. Initial Training:',
                '  • Train candidate models for each modality',
                '  • Cross-validation evaluation',
                'C. Optimization:',
                '  • Hyperparameter tuning',
                'D. Final Selection:',
                '  • Select best performing models'
            ],
            'color': '#FFEAA7'
        },
        'Phase 6: Model Training': {
            'position': (1, 8),
            'steps': [
                'A. Training Setup:',
                '  • Model initialization with best params',
                '  • Training configuration and callbacks',
                'B. Training Execution:',
                '  • Full training on train+validation data',
                '  • Monitor training progress for both modalities',
                'C. Validation:',
                '  • Cross-validation assessment',
                'D. Model Persistence:',
                '  • Save trained models and artifacts'
            ],
            'color': '#DDA0DD'
        },
        'Phase 7: Model Evaluation': {
            'position': (1, 6),
            'steps': [
                'A. Comprehensive Evaluation:',
                '  • Test set performance metrics',
                '  • Confusion matrices for both modalities',
                '  • ROC curves and AUC scores',
                'B. Multimodal Analysis:',
                '  • Individual modality performance',
                '  • Fusion strategy effectiveness',
                'C. Clinical Relevance:',
                '  • Performance vs clinical thresholds',
                '  • Error analysis and interpretability'
            ],
            'color': '#87CEEB'
        },
        'Phase 8: Research Hypothesis Evaluation': {
            'position': (1, 4),
            'steps': [
                'A. Hypothesis Testing:',
                '  • Evaluate H3a vs H30',
                '  • Performance threshold analysis (≥75%)',
                '  • Clinical decision support assessment',
                'B. Results Documentation:',
                '  • Research conclusions for multimodal approach',
                '  • Clinical recommendations',
                'C. Final Deliverables:',
                '  • Save best models in HDF5 format',
                '  • Comprehensive documentation'
            ],
            'color': '#98FB98'
        }
    }
    
    # Set up the plot with more space
    ax.set_xlim(-1, 28)
    ax.set_ylim(2, 20)
    ax.axis('off')
    
    # Title
    fig.suptitle('Audio and Text Classification Development Life Cycle\nMultimodal Workflow Pipeline', 
                fontsize=24, fontweight='bold', y=0.95)
    
    # Draw phases as boxes with steps
    box_width = 8.5  # Reduced width to prevent overlap
    box_height = 1.4
    
    for phase_name, phase_data in phases.items():
        x, y = phase_data['position']
        color = phase_data['color']
        steps = phase_data['steps']
        
        # Create main phase box
        phase_box = FancyBboxPatch(
            (x, y), box_width, box_height,
            boxstyle="round,pad=0.1",
            facecolor=color,
            edgecolor='black',
            linewidth=2,
            alpha=0.8
        )
        ax.add_patch(phase_box)
        
        # Add phase title without icon
        ax.text(x + box_width/2, y + box_height - 0.3, phase_name, 
                ha='center', va='center', fontsize=11, fontweight='bold', 
                color='white', bbox=dict(boxstyle="round,pad=0.2", facecolor='black', alpha=0.7))
        
        # Add steps in a box next to the phase - positioned to avoid overlap
        steps_x = x + box_width + 0.5  # More spacing
        steps_box_width = 16  # Wider steps box
        steps_box_height = box_height
        
        # Create steps box
        steps_box = FancyBboxPatch(
            (steps_x, y), steps_box_width, steps_box_height,
            boxstyle="round,pad=0.05",
            facecolor='white',
            edgecolor=color,
            linewidth=2,
            alpha=0.9
        )
        ax.add_patch(steps_box)
        
        # Add steps text with better formatting
        steps_text = '\n'.join(steps)
        ax.text(steps_x + 0.3, y + steps_box_height - 0.1, steps_text,
                ha='left', va='top', fontsize=9, 
                bbox=dict(boxstyle="round,pad=0.1", facecolor=color, alpha=0.1))
        
        # Draw arrow to next phase (except for last phase)
        if y > 4:
            arrow_start_x = x + box_width/2
            arrow_start_y = y - 0.1
            arrow_end_y = y - 0.9
            
            ax.annotate('', xy=(arrow_start_x, arrow_end_y), 
                       xytext=(arrow_start_x, arrow_start_y),
                       arrowprops=dict(arrowstyle='->', lw=3, color='darkblue'))
    
    # Add workflow statistics box - positioned to avoid overlap
    stats_text = """PIPELINE STATISTICS
    
• Total Phases: 8
• Development Steps: 50+
• Model Types: 6+ algorithms
• Audio Features: MFCCs, spectrograms
• Text Features: TF-IDF, embeddings
• Evaluation Metrics: 10+ metrics
• Target Performance: ≥75% F1-Score
• Output Format: HDF5 model files
• Documentation: Comprehensive"""
    
    ax.text(1, 2.5, stats_text, fontsize=10, 
            bbox=dict(boxstyle="round,pad=0.5", facecolor='lightblue', alpha=0.8, edgecolor='navy'),
            verticalalignment='top')
    
    # Add research question box - positioned separately
    research_text = """RESEARCH FOCUS
    
Research Question:
"How effective is NLP in classifying 
patient symptoms from audio and text 
data on the population level?"

Hypotheses:
• H30: Insufficient precision/recall
• H3a: Sufficient precision/recall for 
       clinical decision support

Success Criteria:
• Accuracy ≥ 75%
• Precision ≥ 75%  
• Recall ≥ 75%
• F1-Score ≥ 75%"""
    
    ax.text(14, 2.5, research_text, fontsize=10,
            bbox=dict(boxstyle="round,pad=0.4", facecolor='lightyellow', alpha=0.9, edgecolor='orange'),
            verticalalignment='top')
    
    # Add legend for phase colors - positioned at bottom
    legend_elements = []
    for i, (phase_name, phase_data) in enumerate(phases.items()):
        phase_short = f"Phase {i+1}"
        legend_elements.append(patches.Patch(color=phase_data['color'], label=phase_short))
    
    ax.legend(handles=legend_elements, loc='lower right', bbox_to_anchor=(0.98, 0.02), 
             fontsize=10, title='Workflow Phases', title_fontsize=11, ncol=4)
    
    # Add data flow indicators - positioned vertically with clear spacing
    flow_labels = [
        (26, 17.5, "Raw Audio & Text"),
        (26, 15.5, "Clean Audio & Text"),
        (26, 13.5, "Processed Data"),
        (26, 11.5, "Feature Vectors"),
        (26, 9.5, "Selected Models"),
        (26, 7.5, "Trained Models"),
        (26, 5.5, "Evaluated Models"),
        (26, 3.5, "Final Models")
    ]
    
    for x, y, label in flow_labels:
        ax.text(x, y, label, fontsize=9, ha='center', va='center',
                bbox=dict(boxstyle="round,pad=0.2", facecolor='lightgreen', alpha=0.6))
    
    # Connect flow labels with lines
    for i in range(len(flow_labels) - 1):
        y1 = flow_labels[i][1] - 0.2
        y2 = flow_labels[i + 1][1] + 0.2
        x = flow_labels[i][0]
        ax.plot([x, x], [y1, y2], 'g--', alpha=0.5, linewidth=1)
    
    return fig, ax

# Function to save the workflow diagram  
def save_workflow_diagram():
    """
    Generate and save the audio and text classification workflow diagram
    """
    try:
        print("Generating Audio and Text Classification Development Life Cycle Workflow Diagram...")
        
        # Create the diagram
        fig, ax = create_audio_text_classification_workflow()
        
        # Create directory if it doesn't exist
        save_dir = r"G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\images\audio_text"
        os.makedirs(save_dir, exist_ok=True)
        
        # Save the diagram with higher DPI for better quality
        save_path = os.path.join(save_dir, "audio_text_classification_workflow_diagram.png")
        fig.savefig(save_path, dpi=400, bbox_inches='tight', facecolor='white', 
                   edgecolor='none', pad_inches=0.5)
        
        print(f"Workflow diagram saved successfully to: {save_path}")
        
        # Display the diagram
        plt.show()
        
        return True
        
    except Exception as e:
        print(f"Error creating/saving diagram: {str(e)}")
        return False

# Main execution
if __name__ == "__main__":
    print("AUDIO AND TEXT CLASSIFICATION DEVELOPMENT LIFE CYCLE WORKFLOW GENERATOR")
    
    # Create and save the 2D diagram
    success = save_workflow_diagram()
    
    if not success:
        print("\nError generating diagram. Please check the error messages above.")
# END OF THE AUDIO AND TEXT CLASSIFICATION DEVELOPMENT LIFE CYCLE WORKFLOW GENERATOR SCRIPT
# ==============================================================================================
# Out:
# AUDIO AND TEXT CLASSIFICATION DEVELOPMENT LIFE CYCLE WORKFLOW GENERATOR
# Generating Audio and Text Classification Development Life Cycle Workflow Diagram...
# All required packages imported successfully
# Workflow diagram saved successfully to: G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\images\audio_text\audio_text_classification_workflow_diagram.png
# Workflow diagram saved successfully to: G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\images\audio_text\audio_text_classification_workflow_diagram.png

# %% [markdown]
# ### Phase1: NLP and Deep Learning for Audio and Text Classification in Medical Diagnosis
#
# Audio and Text Classification Research Question
#
# RQ3: How effective is NLP in classifying patient symptoms from audio and text data on the population level?
# - **H30**: Audio and text analysis of patient symptoms yields both precision and recall metrics that are insufficient for effective provider decision support.
# - **H3a**: Audio and text analysis of patient symptoms results in precision and recall sufficient for provider decision support.

# %%
# Print the Audio and Text Classification Research Question and Hypotheses
print("=" * 80)
print("AUDIO AND TEXT CLASSIFICATION RESEARCH QUESTIONS AND HYPOTHESES")
print("=" * 80)
print("\nRQ3: What is the effectiveness of the audio processing algorithm in classifying patient symptoms from audio data on the population level?\n")
print("- H30: Audio and text analysis of patient symptoms yields both precision and recall metrics that are insufficient for effective provider decision support.")
print("- H3a: Audio and text analysis of patient symptoms results in precision and recall sufficient for provider decision support.")
print("=" * 80)
print("PHASE 1 COMPLETED: PROBLEM DEFINITION")
print("=" * 80)
# END OF PHASE 1: AUDIO PROBLEM DEFINITION SCRIPT
# =============================================================================
# Out:
# ...
# AUDIO AND TEXT CLASSIFICATION RESEARCH QUESTIONS AND HYPOTHESES
# ...
#
# RQ3: What is the effectiveness of the audio processing algorithm in classifying patient symptoms from audio data on the population level?
#
# - H30: Audio and text analysis of patient symptoms yields both precision and recall metrics that are insufficient for effective provider decision support.
# - H3a: Audio and text analysis of patient symptoms results in precision and recall sufficient for provider decision support.
# ...
# PHASE 1 COMPLETED: PROBLEM DEFINITION
# ...

# %% [markdown]
# ### Phase 2: Audio and Text Data Foundation and Exploration (Data Collection)
#
# This section implements the **data foundation** phase of our audio classification pipeline, analyzing a medical audio dataset with patient recordings across 25 diagnostic categories.
#
# **Key Elements:**
# - **Audio Files (`file_name`)**: Audio file paths that will serve as input features for processing
# - **Diagnostic Categories (`prompt`)**: Classification targets, including conditions like "Heart hurts", "Joint pain", and "Skin issue"
# - **Patient Descriptions (`phrase`)**: Raw symptom reports that will serve as input features
# - **Distribution Analysis**: Visualizes class imbalance across diagnostic categories
# - **Data Quality Assessment**: Identifies missing files, invalid audio data, and other quality concerns before preprocessing

# %%
# Phase 2: Audio and Text Data Foundation and Exploration (Data Collection)

try:
    # Step 1. Load raw data
    print("=" * 80)
    print("1. Load raw data")
    print("=" * 80)

    # Define the dataset path
    data_path = r'G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\data\Medical Speech, Transcription, and Intent\overview-of-recordings.csv'

    # Load the dataset with a loading bar
    # Simulate loading with progress bar
    with tqdm(total=100, desc="Loading data", bar_format="{l_bar}{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}]", colour='blue') as pbar:
        for i in range(9):  # Reduced to 9 iterations (90%)
            time.sleep(0.1)  # Simulate loading time
            pbar.update(10)
        df = pd.read_csv(data_path)
        pbar.update(10)  # Final update to reach 100%

    print(f"Successfully loaded {len(df)} records from dataset.")

    # Step 2. Identify key variables for research
    print("\n" + "=" * 80)
    print("2. Identify key variables for research")
    print("=" * 80)
    key_fields = ['file_name', 'phrase', 'prompt']
    print(f"Key variables identified: {key_fields}")
    print("\nDescription of key variables:")
    print("- file_name: Audio file path (input features for audio processing)")
    print("- phrase: Patient's symptom description text (input features for text processing)")
    print("- prompt: Diagnostic category (target variable for classification)")

    # Analyze diagnostic categories sorted by frequency
    diagnostic_categories = df['prompt'].value_counts()
    print(f"\nTotal unique diagnostic categories found: {len(diagnostic_categories)}")
    print("\nAll diagnostic categories by number of records:")
    display(diagnostic_categories)

    # Step 3. Print sample data for each diagnostic category
    print("\n" + "=" * 80)
    print("3. Print sample data for each diagnostic category")
    print("=" * 80)

    # Display one example from each diagnostic category with sample counts
    samples = []
    for category in diagnostic_categories.index:  # Already sorted highest to lowest
        sample = df[df['prompt'] == category][key_fields].iloc[0]
        count = diagnostic_categories[category]
        
        # Create sample entry with count
        sample_entry = {
            'Samples': count,
            'file_name': sample['file_name'],
            'phrase': sample['phrase'],
            'prompt': sample['prompt']
        }
        samples.append(sample_entry)

    samples_df = pd.DataFrame(samples)

    # Set display options for better formatting
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_colwidth', 50)
    pd.set_option('display.width', None)

    display(samples_df)

    # Reset display options
    pd.reset_option('display.max_columns')
    pd.reset_option('display.max_colwidth')
    pd.reset_option('display.width')

    # Step 4. Initial data quality assessment
    print("\n" + "=" * 80)
    print("4. Initial data quality assessment")
    print("=" * 80)

    # Check for missing values
    missing_values = df[key_fields].isnull().sum()
    print("Missing values in key fields:")
    print(missing_values)

    # Check for duplicates
    true_duplicates = df.duplicated(subset=key_fields).sum()
    filename_duplicates = df.duplicated(subset=['file_name']).sum()
    text_duplicates = df.duplicated(subset=['phrase']).sum()
    label_duplicates = df.duplicated(subset=['prompt']).sum()

    print(f"\nDuplication Analysis:")
    print(f"- Complete duplicates (same file + text + diagnosis): {true_duplicates}")
    print(f"- Filename-only duplicates (same audio file): {filename_duplicates}")
    print(f"- Text-only duplicates (same symptom description): {text_duplicates}")
    print(f"- Label-only duplicates (same diagnosis): {label_duplicates}")
    print(f"- Percentage of duplicated records: {true_duplicates/len(df)*100:.2f}%")

    # Check audio file accessibility
    print(f"\nAudio File Accessibility Analysis:")
    audio_base_path = r'G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\data\Medical Speech, Transcription, and Intent\recordings'
    
    # Check if audio files exist in any of the subdirectories
    existing_files = 0
    missing_files = 0
    valid_files = []
    
    # Check in train, test, validate subdirectories
    audio_subdirs = ['train', 'test', 'validate']
    
    for file_name in df['file_name']:
        file_found = False
        for subdir in audio_subdirs:
            file_path = os.path.join(audio_base_path, subdir, file_name)
            if os.path.exists(file_path):
                existing_files += 1
                valid_files.append(file_name)
                file_found = True
                break
        
        if not file_found:
            missing_files += 1
    
    accessibility_rate = (existing_files / len(df)) * 100
    print(f"- Total audio files in dataset: {len(df)}")
    print(f"- Accessible files: {existing_files}")
    print(f"- Missing files: {missing_files}")
    print(f"- File accessibility rate: {accessibility_rate:.2f}%")

    # Text data quality analysis
    print(f"\nText Data Quality Analysis:")
    text_lengths = df['phrase'].str.len()
    print(f"- Average text length: {text_lengths.mean():.1f} characters")
    print(f"- Minimum text length: {text_lengths.min()} characters")
    print(f"- Maximum text length: {text_lengths.max()} characters")
    print(f"- Empty or very short texts (< 10 chars): {(text_lengths < 10).sum()}")

    # Step 5. Create EDA visualizations
    print("\n" + "=" * 80)
    print("5. Create EDA visualizations")
    print("=" * 80)

    # Create output directory for images
    image_dir = r'G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\images\audio_text'
    if not os.path.exists(image_dir):
        os.makedirs(image_dir, exist_ok=True)
        print(f"Created image directory: {image_dir}")

    # DEFINE MISSING VARIABLES PROPERLY
    categories = diagnostic_categories.index
    counts = diagnostic_categories.values
    n_categories = len(diagnostic_categories)
    
    # Create an additional version for better label readability
    print("\nCreating complementary visualization for better label readability...")

    plt.figure(figsize=(20, 12))

    # Create horizontal bar chart for better label readability
    if n_categories <= 25:
        # Show all categories if 25 or fewer
        display_categories = categories
        display_counts = counts
    else:
        # Show top 25 categories for clarity
        display_categories = categories[:25]
        display_counts = counts[:25]

    # Create horizontal bar chart
    bars = plt.barh(range(len(display_categories)), display_counts, 
                    color=plt.cm.viridis(display_counts / max(display_counts)), 
                    alpha=0.8, edgecolor='black', linewidth=0.5)

    # Customize the chart
    plt.xlabel('Number of Audio & Text Records', fontsize=14, fontweight='bold')
    plt.ylabel('Diagnostic Categories', fontsize=14, fontweight='bold')
    plt.title(f'Distribution of {"All" if n_categories <= 25 else "Top 25"} Diagnostic Categories\n(Audio & Text Classification Dataset - Horizontal View)', 
              fontsize=16, fontweight='bold', pad=20)

    # Set y-axis labels
    plt.yticks(range(len(display_categories)), display_categories, fontsize=10)

    # Add value labels on bars
    for i, (bar, count) in enumerate(zip(bars, display_counts)):
        plt.text(bar.get_width() + max(display_counts) * 0.01, bar.get_y() + bar.get_height()/2, 
                 f'{int(count)}', ha='left', va='center', fontweight='bold', fontsize=9)

    # Add grid for better readability
    plt.grid(axis='x', alpha=0.3, linestyle='--')

    # Invert y-axis to show highest values at top
    plt.gca().invert_yaxis()

    # Adjust layout
    plt.tight_layout()

    # Save the version
    output_path_2d = os.path.join(image_dir, "audio_text_2d_diagnostic_categories.png")
    plt.savefig(output_path_2d, dpi=300, bbox_inches='tight', facecolor='white')
    print(f"visualization saved to: {output_path_2d}")

    # Display the 2D visualization
    plt.show()
    plt.close()

    print(f"\nCreated clear visualizations for all {n_categories} diagnostic categories")
    print(f"Images saved to: {image_dir}")

    # Create comprehensive visualization dashboard
    plt.figure(figsize=(24, 20))  # Increased figure size to accommodate more categories

    # 1. Class distribution - ALL 25 categories
    plt.subplot(2, 3, 1)
    # Use all diagnostic categories instead of just top 15
    sns.barplot(y=diagnostic_categories.index, x=diagnostic_categories.values, palette='viridis')
    plt.title(f'All {len(diagnostic_categories)} Diagnostic Categories (Audio & Text)', fontsize=14)
    plt.xlabel('Number of Records')
    plt.ylabel('Diagnostic Category')
    # Adjust font size for better readability with more categories
    plt.tick_params(axis='y', labelsize=8)

    # 2. Audio file name length distribution
    plt.subplot(2, 3, 2)
    filename_lengths = df['file_name'].str.len()
    sns.histplot(data=df.assign(filename_length=filename_lengths), x='filename_length', bins=50, kde=True)
    plt.title('Distribution of Audio File Name Lengths', fontsize=14)
    plt.xlabel('Number of Characters in Filename')
    plt.ylabel('Frequency')

    # 3. Text length distribution
    plt.subplot(2, 3, 3)
    text_lengths = df['phrase'].str.len()
    sns.histplot(data=df.assign(text_length=text_lengths), x='text_length', bins=50, kde=True)
    plt.title('Distribution of Text Lengths', fontsize=14)
    plt.xlabel('Number of Characters in Text')
    plt.ylabel('Frequency')

    # 4. Class imbalance heatmap - ALL 25 categories
    plt.subplot(2, 3, 4)
    class_imbalance = pd.DataFrame({
        'Category': diagnostic_categories.index,  # Use all categories
        'Count': diagnostic_categories.values,
        'Percentage': diagnostic_categories.values / diagnostic_categories.values.sum() * 100
    })
    # Create heatmap with all categories
    sns.heatmap(class_imbalance.set_index('Category')[['Percentage']], 
                annot=True, cmap='viridis', fmt='.1f',
                cbar_kws={'label': 'Percentage'})
    plt.title(f'Class Imbalance Analysis (All {len(diagnostic_categories)} Categories)', fontsize=14)
    # Adjust font size for y-axis labels
    plt.tick_params(axis='y', labelsize=8)

    # 5. Audio vs Text data availability
    plt.subplot(2, 3, 5)
    availability_data = {
        'Audio Files Available': existing_files,
        'Audio Files Missing': missing_files,
        'Text Records Available': len(df) - df['phrase'].isnull().sum(),
        'Text Records Missing': df['phrase'].isnull().sum()
    }
    availability_df = pd.DataFrame(list(availability_data.items()), columns=['Data Type', 'Count'])
    colors = ['green' if 'Available' in item else 'red' for item in availability_df['Data Type']]
    plt.bar(availability_df['Data Type'], availability_df['Count'], color=colors, alpha=0.7)
    plt.title('Audio vs Text Data Availability', fontsize=14)
    plt.ylabel('Count')
    plt.xticks(rotation=45)

    # 6. Data quality summary
    plt.subplot(2, 3, 6)
    quality_data = {
        'Total Records': len(df),
        'Unique Diagnostic Categories': len(diagnostic_categories),
        'Records with Missing Values': df[key_fields].isnull().any(axis=1).sum(),
        'Duplicate Records': true_duplicates,
        'Audio File Accessibility Rate (%)': f"{accessibility_rate:.2f}%",
        'Average Text Length': f"{text_lengths.mean():.1f} chars"
    }
    plt.axis('off')
    plt.table(
        cellText=[[k, str(v)] for k, v in quality_data.items()],
        colLabels=['Metric', 'Value'],
        cellLoc='left',
        loc='center',
        bbox=[0, 0, 1, 1]
    )
    plt.title('Audio & Text Data Quality Summary', fontsize=14)

    plt.tight_layout()
    plt.suptitle('Audio & Text Classification Dataset: Exploratory Data Analysis (All Categories)', fontsize=18, y=1.02)

    # Save comprehensive visualization as PNG and display it
    plt.savefig(os.path.join(image_dir, "audio_text_classification_eda_all_categories.png"), dpi=300, bbox_inches='tight')
    plt.show()  # Display the visualization in the notebook
    plt.close()

    # Create interactive plot with Plotly
    fig = px.bar(
        x=diagnostic_categories.index, 
        y=diagnostic_categories.values,
        title='Interactive Distribution of All Diagnostic Categories (Audio & Text Dataset)',
        labels={'x': 'Diagnostic Category', 'y': 'Number of Records'},
        color=diagnostic_categories.values,
        color_continuous_scale='viridis',
    )

    fig.update_layout(xaxis_tickangle=-45)
    fig.show()  # Display the plotly figure in the notebook

    print(f"Created and saved visualizations to: {image_dir}")
    print("Visualizations were saved as PNG files and displayed in the notebook.")

    # Step 6. Save the dataset with key variables only
    print("\n" + "=" * 80)
    print("6. Save the dataset with key variables only")
    print("=" * 80)

    # Create directory for dataframes if it doesn't exist
    dataframes_dir = r'G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\dataframes\audio_text'
    if not os.path.exists(dataframes_dir):
        os.makedirs(dataframes_dir, exist_ok=True)
        print(f"Created dataframes directory: {dataframes_dir}")

    # Create dataframe with only key variables
    df_to_save = df[key_fields]
    csv_path = os.path.join(dataframes_dir, "phase2_audio_text_initial_df.csv")
    df_to_save.to_csv(csv_path, index=False)

    print(f"Saved dataset with {len(df_to_save)} records and {len(key_fields)} key variables (file_name, phrase, and prompt) to:")
    print(csv_path)

    print("\n" + "=" * 80)
    print("PHASE 2 COMPLETED: AUDIO AND TEXT DATA FOUNDATION AND EXPLORATION ESTABLISHED")
    print("=" * 80)
    
except ImportError as e:
    print("\n" + "=" * 80)
    print(" IMPORT ERROR DETECTED")
    print("=" * 80)
    print(f"Error: {str(e)}")
    print("\n SOLUTION:")
    print("Please import the required packages from the installed libraries to use the needed modules")
    print("and make sure the environment is ready for audio and text classification development.")
    print("\n Required packages that may be missing:")
    print("- pandas (for data manipulation)")
    print("- numpy (for numerical operations)")
    print("- matplotlib (for plotting)")
    print("- seaborn (for statistical visualization)")
    print("- plotly (for interactive plots)")
    print("- tqdm (for progress bars)")
    print("- os (built-in Python module)")
    print("- time (built-in Python module)")
    print("\n To fix this issue:")
    print("1. Go back to the 'Audio and Text Classification Environment Setup' section")
    print("2. Run all the import statements to load the required libraries")
    print("3. Verify that all packages are properly installed")
    print("4. Then re-run this 'Phase 2. Data Foundation' cell")
    print("\n" + "=" * 80)
    raise

except NameError as e:
    print("\n" + "=" * 80)
    print(" NAME ERROR DETECTED")
    print("=" * 80)
    print(f"Error: {str(e)}")
    print("\n SOLUTION:")
    print("Please import the required packages from the installed libraries to use the needed modules")
    print("and make sure the environment is ready for audio and text classification development.")
    print("\n The following variables/modules are not defined:")
    print("This usually means the environment setup section was not run properly.")
    print("\n To fix this issue:")
    print("1. Go back to the 'Audio and Text Classification Environment Setup' section")
    print("2. Run the environment setup cell completely")
    print("3. Ensure all import statements execute successfully")
    print("4. Verify the message 'The environment is now ready for audio and text classification development!' appears")
    print("5. Then re-run this 'Phase 2. Data Foundation' cell")
    print("\n" + "=" * 80)
    raise

except FileNotFoundError as e:
    print("\n" + "=" * 80)
    print(" FILE NOT FOUND ERROR")
    print("=" * 80)
    print(f"Error: {str(e)}")
    print("\n SOLUTION:")
    print("The data file could not be found at the specified path.")
    print("Please verify that:")
    print("1. The data file exists at the specified location")
    print("2. The file path is correct")
    print("3. You have proper read permissions for the file")
    print("\n Expected file location:")
    print("'G:\\Msc\\NCU\\Doctoral Record\\multimodal_medical_diagnosis\\data\\Medical Speech, Transcription, and Intent\\overview-of-recordings.csv'")
    print("\n" + "=" * 80)
    raise

except Exception as e:
    print("\n" + "=" * 80)
    print(" UNEXPECTED ERROR DETECTED")
    print("=" * 80)
    print(f"Error type: {type(e).__name__}")
    print(f"Error message: {str(e)}")
    print("\n SOLUTION:")
    print("An unexpected error occurred during the audio and text data foundation phase.")
    print("Please verify that:")
    print("1. All required libraries are properly imported")
    print("2. The audio and text classification environment setup was completed successfully")
    print("3. The dataset file exists and is accessible")
    print("4. You have sufficient disk space for creating directories and saving files")
    print("\n If the problem persists:")
    print("1. Restart the kernel and run the environment setup again")
    print("2. Check that the dataset contains the expected columns (file_name, phrase, prompt)")
    print("3. Verify that the audio files exist in the recordings subdirectories")
    print("\n" + "=" * 80)
    raise
# END OF THE PHASE 2: AUDIO AND TEXT DATA FOUNDATION AND EXPLORATION (AUDIO AND TEXT DATA COLLECTION) SCRIPT
# ===========================================================================================
# Out:
# ...
# 1. Load raw data
# ...
# Loading data: 100%|██████████| 100/100 [00:00<00:00]
# Successfully loaded 6661 records from dataset.
#
# ...
# 2. Identify key variables for research
# ...
# Key variables identified: ['file_name', 'phrase', 'prompt']
#
# Description of key variables:
# - file_name: Audio file path (input features for audio processing)
# - phrase: Patient's symptom description text (input features for text processing)
# - prompt: Diagnostic category (target variable for classification)
#
# Total unique diagnostic categories found: 25
#
# All diagnostic categories by number of records:
# prompt
# Acne                  328
# Shoulder pain         320
# Joint pain            318
# Infected wound        306
# Knee pain             305
# Cough                 293
# Feeling dizzy         283
# Muscle pain           282
# Heart hurts           273
# Ear ache              270
# Hair falling out      264
# Head ache             263
# Feeling cold          263
# Skin issue            262
# ...

# %% [markdown]
# ### Phase 3: Audio and Text Data Cleaning and Preprocessing (Data Preparation)
#
# This phase focuses on preparing both audio and text data for machine learning by establishing foundations for reliable multimodal classification. The process involves data consistency validation, comprehensive preprocessing pipelines, and proper preparation for feature engineering.
#
# **Audio Processing Components:**
# - **Audio File Standardization**: Uniform sampling rate (22050 Hz), normalization, and format consistency
# - **Noise Reduction**: Spectral gating and basic denoising to improve signal quality
# - **Audio Segmentation**: Consistent duration trimming and padding for uniform input sizes
# - **Temporal Filtering**: Band-pass filtering for voice frequency ranges (80-8000 Hz)
# - **Quality Validation**: File accessibility checks and preprocessing verification
#
# **Text Processing Components:**
# - **Text Normalization**: Case conversion, whitespace handling, and character encoding standardization
# - **Content Validation**: Length checks, empty text handling, and quality assessment
# - **Linguistic Cleaning**: Punctuation normalization while preserving medical terminology
# - **Augmentation Preparation**: Setting up foundation for balanced dataset creation
# - **Encoding Consistency**: Label harmonization between audio and text modalities
#
# **Data Integration Elements:**
# - **Synchronized Splitting**: Maintaining consistent train/validation/test splits across modalities
# - **Cross-Modal Validation**: Ensuring audio-text pairs align correctly in the dataset
# - **Quality Metrics**: Establishing preprocessing success rates for both data types
# - **Error Handling**: Comprehensive exception management for missing or corrupted data
#
# This phase creates the processed foundation that enables effective multimodal feature engineering, ensuring both audio and text data are optimally prepared for subsequent machine learning phases.

# %%
# Phase 3: Audio and Text Data Cleaning and Preprocessing (Data Preparation)

print("=" * 80)
print("PHASE 3: AUDIO AND TEXT DATA CLEANING AND PREPROCESSING (DATA PREPARATION)")
print("=" * 80)

# Import required libraries for multimodal preprocessing
import shutil
from collections import Counter
from sklearn.preprocessing import LabelEncoder, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
import librosa
import soundfile as sf
from scipy import signal
from scipy.signal import butter, filtfilt

# Set up directories and paths for audio and text
project_dir = r"G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis"
audio_dataframes_dir = os.path.join(project_dir, "dataframes", "audio_text")
text_dataframes_dir = os.path.join(project_dir, "dataframes", "audio_text")
variables_dir = os.path.join(project_dir, "variables", "phase3_audio_text")

# Create directories with automatic creation
os.makedirs(audio_dataframes_dir, exist_ok=True)
os.makedirs(text_dataframes_dir, exist_ok=True)
os.makedirs(variables_dir, exist_ok=True)

print(f"Starting Phase 3 with combined audio and text data preparation")
print(f"Project directory: {project_dir}")
print(f"Audio+Text dataframes directory: {audio_dataframes_dir}")
print(f"Variables directory: {variables_dir}")

# A. Audio Data Processing Pipeline
print("\n" + "=" * 80)
print("A. AUDIO DATA PROCESSING PIPELINE")
print("=" * 80)

# Step 1: Load and validate audio-text data consistency
print("\nStep 1: Load and validate audio-text data consistency")
print("-" * 70)

# Load the initial audio and text dataframe from Phase 2
initial_df_path = os.path.join(project_dir, "dataframes", "audio_text", "phase2_audio_text_initial_df.csv")
if os.path.exists(initial_df_path):
    df = pd.read_csv(initial_df_path)
    print(f"Loaded combined dataset with {len(df)} records")
    print(f"Columns: {list(df.columns)}")
else:
    print(f"Combined dataset not found at: {initial_df_path}")
    print("Loading from original source...")
    # Fallback to original source
    data_path = r'G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\data\Medical Speech, Transcription, and Intent\overview-of-recordings.csv'
    df = pd.read_csv(data_path)
    print(f"Loaded {len(df)} records from original dataset")

# Define key variables for consistency
key_fields = ['file_name', 'phrase', 'prompt']
print(f"Key variables for processing: {key_fields}")

# Verify all required fields exist
missing_fields = [field for field in key_fields if field not in df.columns]
if missing_fields:
    print(f"Warning: Missing required fields: {missing_fields}")
    raise ValueError(f"Required fields missing: {missing_fields}")
else:
    print("All required fields present in dataset")

# Create data quality report
print(f"\nData Quality Report:")
print(f"  Total records: {len(df)}")
print(f"  Unique audio files: {df['file_name'].nunique()}")
print(f"  Unique text phrases: {df['phrase'].nunique()}")
print(f"  Diagnostic categories: {df['prompt'].nunique()}")
print(f"  Missing audio files: {df['file_name'].isnull().sum()}")
print(f"  Missing text phrases: {df['phrase'].isnull().sum()}")
print(f"  Missing prompts: {df['prompt'].isnull().sum()}")

# Step 2: Audio file verification and path mapping
print("\nStep 2: Audio file verification and path mapping")
print("-" * 60)

# Set up audio file paths
audio_base_path = os.path.join(project_dir, "data", "Medical Speech, Transcription, and Intent")
recordings_base = os.path.join(audio_base_path, "recordings")
audio_dirs = {
    'train': os.path.join(recordings_base, "train"),
    'test': os.path.join(recordings_base, "test"), 
    'validate': os.path.join(recordings_base, "validate")
}

print(f"Checking audio file accessibility...")
verified_files = 0
missing_files = 0
audio_file_paths = []

for idx, row in df.iterrows():
    file_name = row['file_name']
    file_found = False
    file_path = None
    
    # Check in all three directories
    for dir_name, dir_path in audio_dirs.items():
        if os.path.exists(dir_path):
            full_path = os.path.join(dir_path, file_name)
            if os.path.exists(full_path):
                file_path = full_path
                verified_files += 1
                file_found = True
                break
    
    audio_file_paths.append(file_path)
    
    if not file_found:
        missing_files += 1

# Add audio file paths to dataframe
df['audio_file_path'] = audio_file_paths
df['audio_file_exists'] = df['audio_file_path'].notna()

print(f"Audio file verification results:")
print(f"  Files found: {verified_files}")
print(f"  Files missing: {missing_files}")
print(f"  Accessibility rate: {verified_files/len(df)*100:.2f}%")

# Step 3: Text data validation and cleaning
print("\nStep 3: Text data validation and cleaning")
print("-" * 50)

print("Validating and cleaning text data...")

# Text quality analysis
text_lengths = df['phrase'].str.len()
print(f"Text length statistics:")
print(f"  Mean length: {text_lengths.mean():.1f} characters")
print(f"  Median length: {text_lengths.median():.1f} characters")
print(f"  Min length: {text_lengths.min()} characters")
print(f"  Max length: {text_lengths.max()} characters")

# Identify problematic text entries
empty_text = df['phrase'].isnull() | (df['phrase'].str.strip() == '')
very_short_text = df['phrase'].str.len() < 10
very_long_text = df['phrase'].str.len() > 1000

print(f"Text quality issues:")
print(f"  Empty text entries: {empty_text.sum()}")
print(f"  Very short text (< 10 chars): {very_short_text.sum()}")
print(f"  Very long text (> 1000 chars): {very_long_text.sum()}")

# Basic text cleaning
def clean_text_basic(text):
    """Apply basic text cleaning while preserving medical terminology"""
    if pd.isna(text) or text == '':
        return ''
    
    # Convert to string and basic cleaning
    text = str(text).strip()
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text)
    
    # Basic punctuation normalization (preserve medical terminology)
    text = re.sub(r'([.!?]){2,}', r'\1', text)
    
    return text

# Apply basic cleaning
df['phrase_cleaned'] = df['phrase'].apply(clean_text_basic)

# Validate cleaned text
cleaned_lengths = df['phrase_cleaned'].str.len()
print(f"After basic cleaning:")
print(f"  Mean length: {cleaned_lengths.mean():.1f} characters")
print(f"  Empty after cleaning: {(df['phrase_cleaned'] == '').sum()}")

# Step 4: Label encoding and data consistency
print("\nStep 4: Label encoding and data consistency")
print("-" * 52)

print("Encoding diagnostic labels for consistency...")

# Encode diagnostic categories
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(df['prompt'])
df['encoded_labels'] = encoded_labels

print(f"Label encoding completed:")
print(f"  Unique categories: {len(label_encoder.classes_)}")
print(f"  Encoding range: 0 to {max(encoded_labels)}")

# Display label mapping
print("Label mapping (first 10):")
for i, label in enumerate(label_encoder.classes_[:10]):
    count = np.sum(encoded_labels == i)
    print(f"  {label}: {i} ({count} samples)")
if len(label_encoder.classes_) > 10:
    print(f"  ... and {len(label_encoder.classes_) - 10} more categories")

# Step 5: Data splitting for multimodal consistency
print("\nStep 5: Data splitting for multimodal consistency")
print("-" * 58)

print("Creating consistent train/validation/test splits...")

# Create stratified splits to maintain class distribution
train_data, temp_data, train_labels, temp_labels = train_test_split(
    df, encoded_labels, test_size=0.3, random_state=42, 
    stratify=encoded_labels
)

val_data, test_data, val_labels, test_labels = train_test_split(
    temp_data, temp_labels, test_size=0.5, random_state=42,
    stratify=temp_labels
)

# Add split information to dataframes
train_data = train_data.copy()
val_data = val_data.copy()
test_data = test_data.copy()

train_data['split'] = 'train'
val_data['split'] = 'val'
test_data['split'] = 'test'

# Combine back for final dataframe
df_split = pd.concat([train_data, val_data, test_data], ignore_index=True)

print(f"Data split distribution:")
print(f"  Training: {len(train_data)} samples ({len(train_data)/len(df)*100:.1f}%)")
print(f"  Validation: {len(val_data)} samples ({len(val_data)/len(df)*100:.1f}%)")
print(f"  Test: {len(test_data)} samples ({len(test_data)/len(df)*100:.1f}%)")

# Verify class distribution across splits
print("Class distribution verification:")
for split_name, split_data in [('Train', train_data), ('Val', val_data), ('Test', test_data)]:
    split_dist = Counter(split_data['encoded_labels'])
    print(f"  {split_name}: {len(split_dist)} classes represented")

# B. Integrated Audio Processing Steps
print("\n" + "=" * 80)
print("B. INTEGRATED AUDIO PROCESSING STEPS")
print("=" * 80)

# Step 6: Audio standardization for available files
print("\nStep 6: Audio standardization for available files")
print("-" * 55)

# Filter to only files with valid audio
valid_audio_df = df_split[df_split['audio_file_exists'] == True].copy()
print(f"Processing {len(valid_audio_df)} records with valid audio files")

# Create standardized audio directory
standardized_audio_dir = os.path.join(project_dir, "data", "phase3_step2_standardized_audio")
os.makedirs(standardized_audio_dir, exist_ok=True)

def standardize_audio_file(file_path, target_sr=22050):
    """Standardize audio file to uniform format"""
    try:
        # Load audio file
        y, sr = librosa.load(file_path, sr=target_sr)
        
        # Normalize amplitude
        if np.max(np.abs(y)) > 0:
            y_normalized = y / np.max(np.abs(y))
        else:
            y_normalized = y
        
        return {
            'audio': y_normalized,
            'sample_rate': target_sr,
            'duration': len(y_normalized) / target_sr,
            'success': True
        }
    except Exception as e:
        return {'success': False, 'error': str(e)}

print("Standardizing audio files...")
standardized_count = 0
standardization_results = []

for idx, row in tqdm(valid_audio_df.iterrows(), total=len(valid_audio_df), desc="Standardizing"):
    file_path = row['audio_file_path']
    file_name = row['file_name']
    
    result = standardize_audio_file(file_path)
    
    if result['success']:
        # Save standardized audio
        standardized_path = os.path.join(standardized_audio_dir, file_name)
        sf.write(standardized_path, result['audio'], result['sample_rate'])
        standardized_count += 1
        standardization_results.append({
            'index': idx,
            'standardized_path': standardized_path,
            'duration': result['duration'],
            'success': True
        })
    else:
        standardization_results.append({
            'index': idx,
            'success': False,
            'error': result.get('error', 'Unknown error')
        })

print(f"Audio standardization completed: {standardized_count} files processed")

# Add standardization results to dataframe
for result in standardization_results:
    idx = result['index']
    if result['success']:
        df_split.loc[idx, 'standardized_path'] = result['standardized_path']
        df_split.loc[idx, 'duration'] = result['duration']
        df_split.loc[idx, 'standardization_success'] = True
    else:
        df_split.loc[idx, 'standardization_success'] = False

# Step 7: Basic noise reduction for audio
print("\nStep 7: Basic noise reduction for audio")
print("-" * 45)

# Create noise reduced directory
noise_reduced_dir = os.path.join(project_dir, "data", "phase3_step3_noise_reduced_audio")
os.makedirs(noise_reduced_dir, exist_ok=True)

def basic_noise_reduction(file_path, target_sr=22050):
    """Apply basic noise reduction"""
    try:
        y, sr = librosa.load(file_path, sr=target_sr)
        
        # Basic noise reduction using spectral gating
        # Estimate noise floor
        noise_sample = y[:int(0.5 * sr)] if len(y) > int(0.5 * sr) else y[:len(y)//4]
        noise_floor = np.percentile(np.abs(noise_sample), 95)
        
        # Apply simple noise gating
        y_denoised = np.where(np.abs(y) > noise_floor * 0.1, y, y * 0.1)
        
        # Trim silence
        y_trimmed, _ = librosa.effects.trim(y_denoised, top_db=20)
        
        return {
            'audio': y_trimmed,
            'sample_rate': sr,
            'duration': len(y_trimmed) / sr,
            'success': True
        }
    except Exception as e:
        return {'success': False, 'error': str(e)}

print("Applying basic noise reduction...")
noise_reduced_count = 0

# Process only files that were successfully standardized
standardized_files = df_split[df_split['standardization_success'] == True]

for idx, row in tqdm(standardized_files.iterrows(), total=len(standardized_files), desc="Noise reduction"):
    if pd.notna(row['standardized_path']):
        file_path = row['standardized_path']
        file_name = row['file_name']
        
        result = basic_noise_reduction(file_path)
        
        if result['success']:
            # Save noise reduced audio
            noise_reduced_path = os.path.join(noise_reduced_dir, file_name)
            sf.write(noise_reduced_path, result['audio'], result['sample_rate'])
            
            df_split.loc[idx, 'noise_reduced_path'] = noise_reduced_path
            df_split.loc[idx, 'cleaned_duration'] = result['duration']
            noise_reduced_count += 1

print(f"Noise reduction completed: {noise_reduced_count} files processed")

# C. Text Preprocessing Pipeline
print("\n" + "=" * 80)
print("C. TEXT PREPROCESSING PIPELINE")
print("=" * 80)

# Step 8: Advanced text preprocessing
print("\nStep 8: Advanced text preprocessing")
print("-" * 42)

def preprocess_text_advanced(text):
    """Apply advanced text preprocessing for medical text"""
    if pd.isna(text) or text == '':
        return ''
    
    text = str(text).lower().strip()
    
    # Remove extra punctuation but preserve medical terms
    text = re.sub(r'[^\w\s.,!?-]', ' ', text)
    
    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text)
    
    # Remove very short words (but keep medical abbreviations)
    words = text.split()
    words = [word for word in words if len(word) > 1 or word.lower() in ['i', 'a']]
    
    return ' '.join(words)

print("Applying advanced text preprocessing...")
df_split['text_processed'] = df_split['phrase_cleaned'].apply(preprocess_text_advanced)

# Text statistics after processing
processed_lengths = df_split['text_processed'].str.len()
print(f"Text processing results:")
print(f"  Mean length after processing: {processed_lengths.mean():.1f} characters")
print(f"  Empty texts after processing: {(df_split['text_processed'] == '').sum()}")

# Step 9: Feature extraction preparation
print("\nStep 9: Feature extraction preparation")
print("-" * 45)

print("Preparing features for both modalities...")

# Audio feature preparation indicators
df_split['audio_ready'] = (
    df_split['audio_file_exists'] & 
    df_split['standardization_success'].fillna(False)
)

# Text feature preparation indicators  
df_split['text_ready'] = (
    df_split['text_processed'].str.len() > 5
)

# Combined readiness
df_split['multimodal_ready'] = df_split['audio_ready'] & df_split['text_ready']

print(f"Feature extraction readiness:")
print(f"  Audio ready: {df_split['audio_ready'].sum()} samples")
print(f"  Text ready: {df_split['text_ready'].sum()} samples")
print(f"  Multimodal ready: {df_split['multimodal_ready'].sum()} samples")

# Step 10: Quality validation and final dataset creation
print("\nStep 10: Quality validation and final dataset creation")
print("-" * 62)

print("Performing final quality validation...")

# Create final dataset with only valid samples
final_df = df_split[df_split['multimodal_ready'] == True].copy()

print(f"Final dataset statistics:")
print(f"  Total valid samples: {len(final_df)}")
print(f"  Training samples: {len(final_df[final_df['split'] == 'train'])}")
print(f"  Validation samples: {len(final_df[final_df['split'] == 'val'])}")
print(f"  Test samples: {len(final_df[final_df['split'] == 'test'])}")

# Calculate data retention rates
original_count = len(df)
final_count = len(final_df)
retention_rate = final_count / original_count * 100

print(f"Data retention analysis:")
print(f"  Original samples: {original_count}")
print(f"  Final valid samples: {final_count}")
print(f"  Retention rate: {retention_rate:.1f}%")

# Class distribution in final dataset
final_class_dist = Counter(final_df['encoded_labels'])
print(f"Final class distribution: {len(final_class_dist)} classes")

# D. Save Processed Data and Metadata
print("\n" + "=" * 80)
print("D. SAVE PROCESSED DATA AND METADATA")
print("=" * 80)

print("Saving processed dataframes and metadata...")

# Save main processed dataframe
processed_df_path = os.path.join(audio_dataframes_dir, "phase3_audio_text_processed_df.csv")
final_df.to_csv(processed_df_path, index=False)
print(f"Saved processed dataframe to: {processed_df_path}")

# Save data splits separately for easy access
splits = {
    'train': final_df[final_df['split'] == 'train'],
    'val': final_df[final_df['split'] == 'val'],
    'test': final_df[final_df['split'] == 'test']
}

for split_name, split_data in splits.items():
    split_path = os.path.join(audio_dataframes_dir, f"phase3_audio_text_{split_name}_df.csv")
    split_data.to_csv(split_path, index=False)
    print(f"Saved {split_name} split to: {split_path}")

# Save preprocessing metadata
preprocessing_metadata = {
    'total_samples_processed': len(df_split),
    'final_valid_samples': len(final_df),
    'retention_rate': retention_rate,
    'audio_processing': {
        'files_found': verified_files,
        'files_standardized': standardized_count,
        'files_noise_reduced': noise_reduced_count
    },
    'text_processing': {
        'mean_length_original': float(text_lengths.mean()),
        'mean_length_processed': float(processed_lengths.mean()),
        'empty_texts_removed': int(empty_text.sum())
    },
    'splits': {
        'train_count': len(splits['train']),
        'val_count': len(splits['val']),
        'test_count': len(splits['test'])
    },
    'label_encoding': {
        'num_classes': len(label_encoder.classes_),
        'classes': label_encoder.classes_.tolist()
    }
}

metadata_path = os.path.join(variables_dir, "preprocessing_metadata.json")
with open(metadata_path, 'w') as f:
    json.dump(preprocessing_metadata, f, indent=2)
print(f"Saved preprocessing metadata to: {metadata_path}")

# Save key variables
variables_to_save = {
    'label_encoder': label_encoder,
    'final_df': final_df,
    'preprocessing_metadata': preprocessing_metadata
}

for var_name, var_value in variables_to_save.items():
    var_path = os.path.join(variables_dir, f"{var_name}.joblib")
    joblib.dump(var_value, var_path)
    print(f"Saved {var_name} to: {var_path}")

# Create processing summary
print("\n" + "=" * 80)
print("PHASE 3 COMPLETED: AUDIO AND TEXT DATA CLEANING AND PREPROCESSING")
print("=" * 80)
print("")
print("Processing Summary:")
print("A. Audio Data Processing Pipeline:")
print(f"   ✓ Step 1: Validated {len(df)} audio-text records")
print(f"   ✓ Step 2: Verified {verified_files} audio files ({verified_files/len(df)*100:.1f}% accessible)")
print(f"   ✓ Step 6: Standardized {standardized_count} audio files")
print(f"   ✓ Step 7: Applied noise reduction to {noise_reduced_count} files")
print("")
print("B. Text Processing Pipeline:")
print(f"   ✓ Step 3: Cleaned {len(df)} text samples")
print(f"   ✓ Step 4: Encoded {len(label_encoder.classes_)} diagnostic categories")
print(f"   ✓ Step 8: Advanced preprocessing completed")
print("")
print("C. Data Integration:")
print(f"   ✓ Step 5: Created consistent train/val/test splits")
print(f"   ✓ Step 9: Prepared {final_df['multimodal_ready'].sum()} multimodal samples")
print(f"   ✓ Step 10: Final validation completed with {retention_rate:.1f}% retention")
print("")
print("D. Output Files:")
print(f"   ✓ Processed dataframe: {len(final_df)} samples ready for Phase 4")
print(f"   ✓ Audio files: Standardized and noise-reduced in dedicated directories")
print(f"   ✓ Text data: Cleaned and preprocessed for feature extraction")
print(f"   ✓ Metadata: Comprehensive processing statistics saved")
print("")
print("Ready for Phase 4: Audio and Text Feature Engineering")
# END OF PHASE 3: AUDIO AND TEXT DATA CLEANING AND PREPROCESSING (DATA PREPARATION) SCRIPT
# ================================================================================================
# Out:
# ...
# PHASE 3: AUDIO AND TEXT DATA CLEANING AND PREPROCESSING (DATA PREPARATION)
# ...
# Starting Phase 3 with combined audio and text data preparation
# Project directory: G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis
# Audio+Text dataframes directory: G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\dataframes\audio_text
# Variables directory: G:\Msc\NCU\Doctoral Record\multimodal_medical_diagnosis\variables\phase3_audio_text
#
# ...
# A. AUDIO DATA PROCESSING PIPELINE
# ...
#
# Step 1: Load and validate audio-text data consistency
# ----------------------------------------------------------------------
# Loaded combined dataset with 6661 records
# Columns: ['file_name', 'phrase', 'prompt']
# Key variables for processing: ['file_name', 'phrase', 'prompt']
# All required fields present in dataset
#
# Data Quality Report:
#   Total records: 6661
#   Unique audio files: 6661
#   Unique text phrases: 706
#   Diagnostic categories: 25
#   Missing audio files: 0
#   Missing text phrases: 0
# ...

# %% [markdown]
# ### Phase 4: Audio and Text  Feature Engineering and Selection

# %% [markdown]
# ### Phase 5: Audio and Text Model Selection

# %% [markdown]
# ### Phase 6: Audio and Text Model Training

# %% [markdown]
# ### Phase 7: Audio and Text Model Evaluation

# %% [markdown]
# #### 7.1: Audio and Text Classification Research Hypothesis Evaluation
